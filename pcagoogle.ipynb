# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudioLadisa/plugin/blob/main/pcagoogle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
viterbo = pd.read_csv("PCA.csv")

# %%
viterbo.head()
# Out:
#         area  id  angolo  PCA1mean  PCA1stdev   PCA1min   PCA1max  PCA2mean  \
# 0  33089.767   0    90.0 -3.524160   0.530149 -4.390504 -1.937754 -2.325755
# 1  16994.755   1    90.0 -1.287440   0.915659 -2.400860  0.466036 -1.909963
# 2   5198.399   2    90.0 -2.650833   0.801341 -3.620684 -1.658204 -2.082125
# 3  30290.678   3    90.0 -3.397203   0.316957 -4.099440 -2.587804 -2.353054
# 4   9996.896   4    90.0 -3.367592   0.332082 -3.928305 -2.642882 -2.039184
#
#    PCA2stdev   PCA2min   PCA2max  PCA3mean  PCA3stdev   PCA3min   PCA3max
# 0   0.279024 -2.743290 -1.419368 -0.576277   0.329249 -0.974756  0.973528
# 1   0.286938 -2.334472 -1.241328 -1.082918   0.342346 -1.663251 -0.554700
# 2   0.146141 -2.204673 -1.876726 -0.548419   0.216232 -0.823890 -0.295700
# 3   0.233870 -2.689341 -1.870295 -0.724393   0.217960 -1.146925 -0.364085
# 4   0.331388 -2.328260 -1.147213 -0.436911   0.266173 -0.675142  0.221467

# %%
viterbo.describe()
# Out:
#                area          id      angolo    PCA1mean   PCA1stdev  \
# count    145.000000  145.000000  141.000000  145.000000  145.000000
# mean   18691.385966   72.000000   70.212766   -2.450410    0.453397
# std    15153.880151   42.001984   37.406418    1.023757    0.283470
# min     1599.506000    0.000000    0.000000   -5.046224    0.042595
# 25%     8697.160000   36.000000   90.000000   -3.113665    0.307363
# 50%    14295.461000   72.000000   90.000000   -2.525833    0.379379
# 75%    24591.828000  108.000000   90.000000   -1.737172    0.512019
# max    87073.824000  144.000000   90.000000    0.649282    2.491677
#
#           PCA1min     PCA1max    PCA2mean   PCA2stdev     PCA2min     PCA2max  \
# count  145.000000  145.000000  145.000000  145.000000  145.000000  145.000000
# mean    -3.191232   -1.405748   -2.198855    0.243805   -2.553494   -1.564286
# std      1.037513    1.228255    0.435293    0.176683    0.331823    0.837496
# ...

# %%
# %matplotlib inline

# %%
viterbo_angolo = viterbo[['PCA1mean','angolo']]
viterbo_angolo.plot(kind="scatter", x='angolo',y='PCA1mean')

# %%
viterbo_angolo2 = viterbo[['PCA2mean','angolo']]
viterbo_angolo2.plot(kind="scatter", x='angolo',y='PCA2mean')

# %%
viterbo_angolo3 = viterbo[['PCA3mean','angolo']]
viterbo_angolo3.plot(kind="scatter", x='angolo',y='PCA3mean')
